# %% [markdown]
# THE SPARKS FOUNDATION #GRIPJUNE24

# %% [markdown]
# Author: SHREEMATHI.G.S
#
# Data Science & Business Analytics Intern

# %% [markdown]
# TASK3- Exploratory Data Analysis-Terrorism

# %%
#Importing of libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path='/content/drive/MyDrive/Dataset/Terrorism (1).csv'
df=pd.read_csv(path)
df
# Out:
# <ipython-input-2-da5f94f65219>:2: DtypeWarning: Columns (4,31,33,61,62,76,79,90,92,94,96,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv(path)
#             eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0      197000000000   1970       7     2        NaN         0        NaN
# 1      197000000000   1970       0     0        NaN         0        NaN
# 2      197001000000   1970       1     0        NaN         0        NaN
# 3      197001000000   1970       1     0        NaN         0        NaN
# 4      197001000000   1970       1     0        NaN         0        NaN
# ...             ...    ...     ...   ...        ...       ...        ...
# 65530  199706000000   1997       6     5        NaN         0        NaN
# 65531  199706000000   1997       6     5        NaN         0        NaN
# 65532  199706000000   1997       6     5        NaN         0        NaN
# 65533  199706000000   1997       6     5        NaN         0        NaN
# 65534  199706000000   1997       6     5        NaN         0        NaN
#
#        country         country_txt  region  ... addnotes scite1 scite2  \
# 0           58  Dominican Republic       2  ...      NaN    NaN    NaN
# 1          130              Mexico       1  ...      NaN    NaN    NaN
# 2          160         Philippines       5  ...      NaN    NaN    NaN
# 3           78              Greece       8  ...      NaN    NaN    NaN
# 4          101               Japan       4  ...      NaN    NaN    NaN
# ...        ...                 ...     ...  ...      ...    ...    ...
# 65530        6             Algeria      10  ...      NaN    NaN    NaN
# 65531       90             Hungary       9  ...      NaN    NaN    NaN
# 65532       90             Hungary       9  ...      NaN    NaN    NaN
# 65533       90             Hungary       9  ...      NaN    NaN    NaN
# 65534       90             Hungary       9  ...      NaN    NaN    NaN
#
#        scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 0         NaN      PGIS        0         0        0       0
# 1         NaN      PGIS        0         1        1       1
# 2         NaN      PGIS       -9        -9        1       1
# 3         NaN      PGIS       -9        -9        1       1
# 4         NaN      PGIS       -9        -9        1       1
# ...       ...       ...      ...       ...      ...     ...
# 65530     NaN      PGIS       -9        -9       -9      -9
# 65531     NaN      PGIS       -9        -9        0      -9
# 65532     NaN      PGIS       -9        -9        0      -9
# 65533     NaN      PGIS       -9        -9        0      -9
# 65534     NaN      PGIS       -9        -9        0      -9
#
#                                                  related
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65530                                                NaN
# 65531  199706050003, 199706050004, 199706050004, 1997...
# 65532  199706050003, 199706050004, 199706050005, 1997...
# 65533  199706050005, 199706050003, 199706050004, 1997...
# 65534  199706050006, 199706050003, 199706050004, 1997...
#
# [65535 rows x 135 columns]

# %%
df.isna().sum()
# Out:
# eventid           0
# iyear             0
# imonth            0
# iday              0
# approxdate    65505
#               ...
# INT_LOG           0
# INT_IDEO          0
# INT_MISC          0
# INT_ANY           0
# related       58769
# Length: 135, dtype: int64

# %%
df.describe()
# Out:
#             eventid         iyear        imonth          iday      extended  \
# count  6.553500e+04  65535.000000  65535.000000  65535.000000  65535.000000
# mean   1.986616e+11   1986.552193      6.392447     15.390402      0.018738
# std    6.336636e+08      6.337192      3.405159      8.807574      0.135600
# min    1.970000e+11   1970.000000      0.000000      0.000000      0.000000
# 25%    1.982060e+11   1982.000000      3.000000      8.000000      0.000000
# 50%    1.987110e+11   1987.000000      6.000000     15.000000      0.000000
# 75%    1.991110e+11   1991.000000      9.000000     23.000000      0.000000
# max    1.997060e+11   1997.000000     12.000000     31.000000      1.000000
#
#             country        region      latitude     longitude   specificity  \
# count  65535.000000  65535.000000  62059.000000  6.205800e+04  65535.000000
# mean     147.549020      5.677379     18.127411 -1.402178e+03      1.431754
# std      133.846628      3.199408     24.486707  3.459691e+05      1.109175
# min        4.000000      1.000000    -53.154613 -8.618590e+07      1.000000
# 25%       61.000000      3.000000      5.549162 -7.569456e+01      1.000000
# 50%      110.000000      6.000000     15.047369 -3.696263e+00      1.000000
# 75%      183.000000      8.000000     38.395649  3.481189e+01      1.000000
# max      605.000000     12.000000     64.837778  1.784419e+02      5.000000
#
#        ...     ransomamt  ransomamtus    ransompaid  ransompaidus  \
# count  ...  6.540000e+02          1.0  1.600000e+02      5.000000
# mean   ...  3.435298e+06      20000.0  1.277140e+06  13395.000000
# std    ...  3.988998e+07          NaN  4.632614e+06  18683.535533
# min    ...  0.000000e+00      20000.0  0.000000e+00      0.000000
# 25%    ...  0.000000e+00      20000.0  0.000000e+00      0.000000
# 50%    ...  2.050000e+04      20000.0  3.135000e+04    650.000000
# 75%    ...  5.737500e+05      20000.0  4.020000e+05  26325.000000
# max    ...  1.000000e+09      20000.0  4.100000e+07  40000.000000
#
#        hostkidoutcome    nreleased       INT_LOG      INT_IDEO      INT_MISC  \
# count     1575.000000  1219.000000  65535.000000  65535.000000  65535.000000
# mean         3.125714     7.306809     -3.628534     -3.589090      0.128771
# std          1.462602    34.817908      4.479267      4.531547      0.794551
# min          2.000000   -99.000000     -9.000000     -9.000000     -9.000000
# 25%          2.000000     1.000000     -9.000000     -9.000000      0.000000
# 50%          2.000000     1.000000      0.000000      0.000000      0.000000
# 75%          4.000000     3.000000      0.000000      0.000000      0.000000
# max          7.000000   390.000000      1.000000      1.000000      1.000000
#
#             INT_ANY
# count  65535.000000
# mean      -2.857221
# std        4.479471
# min       -9.000000
# 25%       -9.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
#
# [8 rows x 78 columns]

# %%
df.nunique()
# Out:
# eventid        329
# iyear           27
# imonth          13
# iday            32
# approxdate      26
#               ...
# INT_LOG          3
# INT_IDEO         3
# INT_MISC         3
# INT_ANY          3
# related       5500
# Length: 135, dtype: int64

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':"day",'gname':'Group','country_txt':'Country','region_txt':'Region','provstate':'State','city':'City','latitude':'latitude',
    'longitude':'longitude','summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','weaptype1_txt':'Weapon','nkill':'kill',
     'nwound':'Wound'},inplace=True)
df
# Out:
#             eventid  Year  Month  day approxdate  extended resolution  \
# 0      197000000000  1970      7    2        NaN         0        NaN
# 1      197000000000  1970      0    0        NaN         0        NaN
# 2      197001000000  1970      1    0        NaN         0        NaN
# 3      197001000000  1970      1    0        NaN         0        NaN
# 4      197001000000  1970      1    0        NaN         0        NaN
# ...             ...   ...    ...  ...        ...       ...        ...
# 65530  199706000000  1997      6    5        NaN         0        NaN
# 65531  199706000000  1997      6    5        NaN         0        NaN
# 65532  199706000000  1997      6    5        NaN         0        NaN
# 65533  199706000000  1997      6    5        NaN         0        NaN
# 65534  199706000000  1997      6    5        NaN         0        NaN
#
#        country             Country  region  ... addnotes scite1 scite2  \
# 0           58  Dominican Republic       2  ...      NaN    NaN    NaN
# 1          130              Mexico       1  ...      NaN    NaN    NaN
# 2          160         Philippines       5  ...      NaN    NaN    NaN
# 3           78              Greece       8  ...      NaN    NaN    NaN
# 4          101               Japan       4  ...      NaN    NaN    NaN
# ...        ...                 ...     ...  ...      ...    ...    ...
# 65530        6             Algeria      10  ...      NaN    NaN    NaN
# 65531       90             Hungary       9  ...      NaN    NaN    NaN
# 65532       90             Hungary       9  ...      NaN    NaN    NaN
# 65533       90             Hungary       9  ...      NaN    NaN    NaN
# 65534       90             Hungary       9  ...      NaN    NaN    NaN
#
#        scite3  dbsource  INT_LOG  INT_IDEO INT_MISC INT_ANY  \
# 0         NaN      PGIS        0         0        0       0
# 1         NaN      PGIS        0         1        1       1
# 2         NaN      PGIS       -9        -9        1       1
# 3         NaN      PGIS       -9        -9        1       1
# 4         NaN      PGIS       -9        -9        1       1
# ...       ...       ...      ...       ...      ...     ...
# 65530     NaN      PGIS       -9        -9       -9      -9
# 65531     NaN      PGIS       -9        -9        0      -9
# 65532     NaN      PGIS       -9        -9        0      -9
# 65533     NaN      PGIS       -9        -9        0      -9
# 65534     NaN      PGIS       -9        -9        0      -9
#
#                                                  related
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 65530                                                NaN
# 65531  199706050003, 199706050004, 199706050004, 1997...
# 65532  199706050003, 199706050004, 199706050005, 1997...
# 65533  199706050005, 199706050003, 199706050004, 1997...
# 65534  199706050006, 199706050003, 199706050004, 1997...
#
# [65535 rows x 135 columns]

# %%
year = df['Year'].unique()
years_count = df['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (18,10))
sns.barplot(x = year,
           y = years_count,
           color='blue')
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize=20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Attacks In Years',fontsize=30)
plt.show()

# %%
attack = data.Country.value_counts()[:10]
attack
# Out:
# Country
# Peru                5987
# Colombia            5554
# El Salvador         5318
# United Kingdom      3996
# India               2743
#                     ...
# Vatican City           1
# New Hebrides           1
# South Vietnam          1
# Andorra                1
# Falkland Islands       1
# Name: count, Length: 192, dtype: int64

# %%
# Out:
# Group
# Unknown                                             22034
# Shining Path (SL)                                    4476
# Farabundo Marti National Liberation Front (FMLN)     3351
# Irish Republican Army (IRA)                          2631
# Basque Fatherland and Freedom (ETA)                  1759
#                                                     ...
# Iranian Monarchists                                     1
# Anti-Chon radical elements                              1
# Basque Refugee Support Group                            1
# Red Patriots Group                                      1
# Tehrik al-Mojahedin                                     1
# Name: count, Length: 2192, dtype: int64

# %%
pd.crosstab(df.Year, df.Region).plot(kind='area',stacked=False,figsize=(20,10))
plt.title('Terrorist Activities By Region In Each Year',fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel("Year",fontsize=20)
plt.show()
